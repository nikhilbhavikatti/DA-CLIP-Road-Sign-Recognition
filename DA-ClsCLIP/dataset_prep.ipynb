# %% [markdown]
# ### know the categories

# %%
import os
from PIL import Image as PILImage
from PIL import ImageEnhance, ImageFilter
from IPython.display import Image, display
import shutil
import numpy as np
import matplotlib.pyplot as plt
import random
import re

def resize224_image(img: PILImage.Image) -> PILImage.Image:
    w, h = img.size
    min_side = min(w, h)

    # Center crop
    left   = (w - min_side) // 2
    top    = (h - min_side) // 2
    right  = left + min_side
    bottom = top + min_side

    img_cropped = img.crop((left, top, right, bottom))
    img_resized = img_cropped.resize((224, 224), PILImage.LANCZOS)

    return img_resized

def augment_image(img):
    method = random.choice(["brightness", "contrast", "noise", "blur", "resize", "rotate"])

    if method == "brightness":
        factor = random.uniform(0.6, 1.4)
        return ImageEnhance.Brightness(img).enhance(factor)

    elif method == "contrast":
        factor = random.uniform(0.6, 1.4)
        return ImageEnhance.Contrast(img).enhance(factor)

    elif method == "noise":
        img_np = np.array(img)
        noise = np.random.normal(0, 15, img_np.shape).astype(np.int16)
        img_np = np.clip(img_np + noise, 0, 255).astype(np.uint8)
        return PILImage.fromarray(img_np)

    elif method == "blur":
        radius = random.uniform(0.5, 2.0)
        return img.filter(ImageFilter.GaussianBlur(radius=radius))
    
    elif method == "resize":
        scale = random.uniform(0.8, 0.9)
        w, h = img.size
        new_w, new_h = int(w * scale), int(h * scale)
        small = img.resize((new_w, new_h), PILImage.LANCZOS)
        new_img = PILImage.new("RGB", (w, h), (255, 255, 255))
        offset = ((w - new_w) // 2, (h - new_h) // 2)
        new_img.paste(small, offset)
        return new_img

    elif method == "rotate":
        angle = random.uniform(-10, 10)
        return img.rotate(angle, resample=PILImage.BICUBIC, expand=False, fillcolor=(255, 255, 255))

    return img

# %%
def augment_folder_overwrite(src_dir, tgt_dir, seed=42):
    os.makedirs(tgt_dir, exist_ok=True)
    fnames = [f for f in os.listdir(src_dir) if f.lower().endswith('.png')]
    random.seed(seed)

    for fname in fnames:
        src_path = os.path.join(src_dir, fname)
        img = PILImage.open(src_path).convert('RGB')

        aug_img = augment_image(img)  # 用你自定义的增强函数
        tgt_path = os.path.join(tgt_dir, fname)
        aug_img.save(tgt_path)

print("增强生成新数据集（文件名不变，仅1个增强结果/图）")
augment_folder_overwrite("train_mx_cn", "train_mx_cn_aug")
augment_folder_overwrite("train_ai_cn", "train_ai_cn_aug")
print("完成！")
# Out:
# 增强生成新数据集（文件名不变，仅1个增强结果/图）
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <module>
#      14 print("增强生成新数据集（文件名不变，仅1个增强结果/图）")
#      15 augment_folder_overwrite("train_mx_cn", "train_mx_cn_aug")
# ---> 16 augment_folder_overwrite("train_ai_cn", "train_ai_cn_aug")
#      17 print("完成！")
#
# Input In [6], in augment_folder_overwrite(src_dir, tgt_dir, seed)
#       6 for fname in fnames:
#       7     src_path = os.path.join(src_dir, fname)
# ----> 8     img = PILImage.open(src_path).convert('RGB')
#      10     aug_img = augment_image(img)  # 用你自定义的增强函数
#      11     tgt_path = os.path.join(tgt_dir, fname)
#
# File c:\Users\J4vix\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:982, in Image.convert(self, mode, matrix, dither, palette, colors)
#     979 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     980     deprecate(mode, 12)
# --> 982 self.load()
#     984 has_transparency = "transparency" in self.info
#     985 if not mode and self.mode == "P":
#     986     # determine default mode
#
# File c:\Users\J4vix\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\ImageFile.py:389, in ImageFile.load(self)
#     386         raise OSError(msg)
#     388 b = b + s
# --> 389 n, err_code = decoder.decode(b)
#     390 if n < 0:
#     391     break
#
# KeyboardInterrupt:

# %% [markdown]
# ### For big dataset
#
# select the target categories from /images to /cn_ft
#
# resize to 224*224 from /cn_ft to /cn_ft_224

# %%
# Mapping from prefix to category name
prefix_map = {
    "000": "speed limit",
    "001": "speed limit",
    "002": "speed limit",
    "003": "speed limit",
    "004": "speed limit",
    "005": "speed limit",
    "006": "speed limit",
    "007": "speed limit",
    # "010": "no proceed straight",
    # "011": "no left turn",
    # "013": "no right turn",
    "014": "no overtaking",
    "015": "no U-turn",
    # "016": "no motor vehicles",
    # "017": "no honking",
    # "018": "end of speed limit",
    # "019": "end of speed limit",
    # "022": "left turn",
    # "024": "right turn",
    "035": "pedestrian crossing",
    "036": "cycle crossing",
    "037": "school zone",
    "040": "steep descent",
    "041": "steep ascent",
    # "042": "slow",
    "047": "railway crossing",
    "048": "road work ahead",
    "050": "railway crossing",
    # "051": "accident ahead",
    "052": "stop",
    # "053": "no entry for all",
    "054": "no stopping",
    "055": "no entry for vehicles",
    "056": "give way",
}

src_folder = "images"
dst_folder = "cn_rl"

os.makedirs(dst_folder, exist_ok=True)

# 分类采样
category_files = {}
for fname in os.listdir(src_folder):
    if not fname.lower().endswith(".png"):
        continue
    prefix = fname[:3]
    if prefix not in prefix_map:
        continue
    category = prefix_map[prefix]
    category_files.setdefault(category, []).append(fname)

# 采样 + resize + 保存
for category, files in category_files.items():
    sampled = random.sample(files, min(20, len(files)))
    safe_cat = category.lower().replace(" ", "_").replace("-", "_")
    for idx, fname in enumerate(sampled):
        new_name = f"{safe_cat}_{idx:03d}.png"
        src_path = os.path.join(src_folder, fname)
        img = PILImage.open(src_path).convert("RGB")
        resized_img = resize224_image(img)
        dst_path = os.path.join(dst_folder, new_name)
        resized_img.save(dst_path)

print("Done.")
# Out:
# Done.

# %% [markdown]
# ### For standard images
#
# resize to 224*224 from /cn_one to /cn_one_224

# %%
src_folder = "cn_one"
dst_folder = "cn_rl"

os.makedirs(dst_folder, exist_ok=True)

for fname in os.listdir(src_folder):
    if not fname.lower().endswith(".png"):
        continue

    src_path = os.path.join(src_folder, fname)
    img = PILImage.open(src_path).convert("RGB")

    # 数据增强 + resize
    augmented = augment_image(img)
    resized = resize224_image(augmented)

    # 保存
    dst_path = os.path.join(dst_folder, fname)
    resized.save(dst_path)

print("Done.")
# Out:
# Done.

# %% [markdown]
# ### For AIGC images

# %%
# 先读取 cn_rl 文件夹里各个类别有多少张图片
def get_category(fname):
    # 假设文件名是 like school_zone_003.png
    return fname.rsplit('_', 1)[0]

def get_max_index_in_folder(folder):
    category_max_idx = {}
    for fname in os.listdir(folder):
        if fname.endswith('.png'):
            cat = get_category(fname)
            idx = int(re.findall(r'_(\d+)\.png$', fname)[0])
            category_max_idx[cat] = max(idx, category_max_idx.get(cat, -1))
    return category_max_idx

# 1. 统计真实图片最大编号
rl_folder = 'cn_rl'
gpt_folder = 'cn_gpt'
ai_folder = 'cn_ai'
os.makedirs(ai_folder, exist_ok=True)

category_max_idx = get_max_index_in_folder(rl_folder)

# 再将 cn_gpt 文件夹里相同类别的下标依次累加，避免覆写，保存在 cn_ai 文件夹
for fname in os.listdir(gpt_folder):
    if fname.endswith('.png'):
        cat = get_category(fname)
        current_idx = category_max_idx.get(cat, -1) + 1
        new_name = f"{cat}_{current_idx:03d}.png"
        src_path = os.path.join(gpt_folder, fname)

        # 加载图片
        img = PILImage.open(src_path).convert("RGB")

        # 数据增强
        augmented = augment_image(img)

        # resize
        resized = resize224_image(augmented)

        # 保存
        dst_path = os.path.join(ai_folder, new_name)
        resized.save(dst_path)
        category_max_idx[cat] = current_idx  # 更新最大编号

print("Done")
# Out:
# Done

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

folder_path = "dataset_cn"

# 存储每个类别的第一张图像
first_images = {}

# 遍历文件夹中所有 .png 文件
for fname in sorted(os.listdir(folder_path)):
    if not fname.lower().endswith(".png"):
        continue
    # 提取类别名（文件名去掉最后一个 _编号部分）
    category = "_".join(fname.split("_")[:-1])
    if category not in first_images:
        first_images[category] = fname

# 加载图像和标题
images = []
titles = []

for category, fname in sorted(first_images.items()):
    img_path = os.path.join(folder_path, fname)
    img = Image.open(img_path)
    images.append(img)
    titles.append(category)

# 显示图像网格
num_images = len(images)
cols = 5
rows = (num_images + cols - 1) // cols

plt.figure(figsize=(15, rows * 3))

for i, (img, title) in enumerate(zip(images, titles)):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(title, fontsize=8)
    plt.axis("off")

plt.tight_layout()
plt.show()
